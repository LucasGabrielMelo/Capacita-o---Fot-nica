# %% [markdown]
# ## Build RIB
#
# Determinando os modos propagantes em um RIB waveguide (guia de onda do tipo RIB), a uma freqência de oscilação $\omega = 193\space THz$

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.sparse as sp
from scipy.sparse import diags, eye, kron, bmat, csr_matrix
from scipy.sparse.linalg import eigs

def mround(x):
    """
    Arredondamento no estilo MATLAB: .5 -> sobe.
    Aceita escalar ou array NumPy.
    """
    return np.floor(x + 0.5).astype(int)

def diff_opr(Nx,Ny,dx,dy): # Creating differentiation matrices, f -> backyard and g -> forward
  M = Nx*Ny
  diagonal = np.ones(M-1)
  diagonal[Nx-1:-1:Nx] = 0
  Dxf = -sp.eye(M,M) + sp.diags(diagonal, 1, shape=(M,M))
  Dyf = sp.eye(M,M,k = Nx) - sp.eye(M,M)
  Dxg = -Dxf.conj().T
  Dyg = -Dyf.conj().T
  return Dxf/dx, Dyf/dy, Dxg/dx, Dyg/dy

micrometers = 1e-6

# lambda reference
lam0 = 1.55 * micrometers # Wavelength in free-space

# number of modes
nmodes = 3

# Grid spacing
dx = 0.2 * micrometers
dy = 0.2 * micrometers
Nx = 10
Ny = 10

# %%
# Rib material
rib_n1 = 1.0 # Refractive indices
rib_n2 = 3.5
rib_n3 = 1.5

# Rib dimension
rib_h  = 0.60 * micrometers # Height of the RIB
rib_t  = 0.60 * micrometers # Height of the slab
rib_w  = 0.80 * micrometers # Length of the RIB

# Extra space
SPACER = lam0 * np.array([1.5, 1.5, 0.5, 0.5])  # [sx_left, sx_right, sy_bottom, sy_top] Other dimensions of the guide

# %% [markdown]
# ### Resolução por comprimento de onda.

# %%
# Grid parameters
nmax   = max(rib_n1, rib_n2, rib_n3) # Maximum refractive index in the guide
NRES   = 20 # Number of points in the wavelength discretization (resolution)

# %%
dx = lam0 / nmax / NRES # In the material, the wavelength is lam0 / n 
dy = lam0 / nmax / NRES # Using the smallest wavelength in the guide to create the grid
print("dx = %.5e - dy = %.5e"%(dx, dy))
# Out:
# dx = 2.21429e-08 - dy = 2.21429e-08

# %% [markdown]
# ### Cálculo da malha

# %%
# Adjust mesh
nx = int(np.ceil(rib_w / dx)) # Number of points needed to represent the guide length
dx = rib_w / nx # Ajusting dx
ny = int(np.ceil(rib_t / dy)) # Number of points needed to represent the slap height
dy = rib_t / ny # Ajusting dy
print("nx = %d - ny = %d"%(nx, ny))
print("dx = %.5e - dy = %.5e"%(dx, dy))
# Out:
# nx = 37 - ny = 28
# dx = 2.16216e-08 - dy = 2.14286e-08

# %%
# Grid size X
Sx = SPACER[0] + rib_w + SPACER[1]
Nx = int(np.ceil(Sx / dx))
Sx = Nx * dx

# Grid size Y
Sy = SPACER[2] + rib_h + rib_t + SPACER[3]
Ny = int(np.ceil(Sy / dy))
Sy = Ny * dy
print("Total size (Nx x Ny) = %d x %d"%(Nx,Ny)) # Dimenções da matriz
print("Total size (Sx x Sy) = %.3g [um] x %.3g [um]"%(1e6*Sx,1e6*Sy)) # Grid dimensions

# Grid - upsample (2x) 
Nx2 = 2 * Nx; dx2 = dx / 2
Ny2 = 2 * Ny; dy2 = dy / 2

# Grid axes
xa  = np.arange(1, Nx + 1) * dx;  xa  = xa  - xa.mean() #xa - xa.mean() 
ya  = np.arange(1, Ny + 1) * dy;  ya  = ya  - ya.mean()

# Upsample grid (2x)
xa2 = np.arange(1, Nx2 + 1) * dx2; xa2 = xa2 - xa2.mean()
ya2 = np.arange(1, Ny2 + 1) * dy2; ya2 = ya2 - ya2.mean()

# Create meshgrid
Yc, Xc = np.meshgrid(ya2, xa2, indexing="xy")
# Out:
# Total size (Nx x Ny) = 253 x 129
# Total size (Sx x Sy) = 5.47 [um] x 2.76 [um]

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 10))

ext = 1e6*np.array([xa2.min()-dx, xa2.max()+dx, ya2.max()+dy, ya2.min()-dy])

ax[0].imshow(Yc.T, extent=ext, aspect="equal")
ax[0].set(xlabel="x", ylabel="y", title=f"{'Y Grid'} - Nx = {Nx2} - Ny = {Ny2}")
ax[0].grid()

ax[1].imshow(Xc.T, extent=ext, aspect="equal")
ax[1].set(xlabel="x", ylabel="y", title=f"{'X Grid'} - Nx = {Nx2} - Ny = {Ny2}")
ax[1].grid()

plt.show()
plt.tight_layout()

# %% [markdown]
# ### Build device

# %%
# Create matrices
ER2 = (rib_n1**2) * np.ones((Nx2, Ny2))
UR2 = np.ones((Nx2, Ny2))

# Create indexes
nx1 = int(mround(SPACER[0] / dx2))                          # Core beginnig in x
nx2i = nx1 + int(mround(rib_w / dx2))                       # exclusive end

ny1 = int(mround(SPACER[2] / dy2))                          # Top of the RIB
ny2i = ny1 + int(mround(rib_h / dy2))                       # Top of the slab
ny3 = ny2i                                                  
ny4i = ny3 + int(mround(rib_t / dy2))                       # Top of buried oxide
ny5 = ny4i

# %%
# Create RIB waveguide

ER2[nx1:nx2i, ny1:ny2i] = rib_n2**2

ER2[:, ny3:ny4i] = rib_n2**2

ER2[:, ny5:Ny2] = rib_n3**2

# %%
fig, ax = plt.subplots(1,2,figsize=(16, 8))

ax[0].imshow(ER2.T, extent=[0, Nx2, Ny2, 0], aspect="equal")
ax[0].set(xlabel="x", ylabel="y", title=f"Nx = {Nx2} - Ny = {Ny2}")
ax[0].set_xticks(np.arange(0, Nx2 + 1, 23))
ax[0].set_yticks(np.arange(0, Ny2 + 1, 21))
ax[0].tick_params(axis='x', labelrotation=90)
ax[0].grid(which='both')

ax[1].imshow(ER2.T, extent=np.array([xa.min(), xa.max(), ya.max(), ya.min()]), aspect="equal")
ax[1].set(xlabel="x", ylabel="y", title=f"Nx = {Nx} - Ny = {Ny}")
ax[1].set_xticks(np.arange(xa.min()-dx/2, xa.max()+dx, 23*dx))
ax[1].set_yticks(np.arange(ya.min()-dy/2, ya.max()+dy, 10*dy))
#ax[1].plot(Xc.ravel(), Yc.ravel(), marker="o", linestyle="None", markersize=2)
ax[1].tick_params(axis='x', labelrotation=90)
ax[1].grid(which='both')

plt.show()
plt.tight_layout()

'''
Na matriz, preenchemos as informações do eixo x e y normalmente, só temos que lembrar de transpolas depois.
'''
# Out:
# '\nNa matriz, preenchemos as informações do eixo x e y normalmente, só temos que lembrar de transpolas depois.\n'

# %%
from matplotlib.ticker import ScalarFormatter

zoomx = 10
zoomy = 5
x_zoom = 1e6*xa2[(nx1-zoomx):(nx2i+zoomx)]
y_zoom = 1e6*ya2[(ny1-zoomy):(ny2i+zoomy)]

xmin, xmax = x_zoom.min(), x_zoom.max()
ymin, ymax = y_zoom.min(), y_zoom.max()

stepx = 1e6*dx2   
stepy = 1e6*dy2   

# All ticks (per cell) and "majors" (per 4 cells)
xticks_all = np.arange(xmin, xmax + 0.5*stepx, stepx)
yticks_all = np.arange(ymin, ymax + 0.5*stepy, stepy)
xticks_major = xticks_all[::4]
yticks_major = yticks_all[::4]

fig, ax = plt.subplots(figsize=(12, 12))

ax.imshow(
    ER2[(nx1-zoomx):(nx2i+zoomx), (ny1-zoomy):(ny2i+zoomy)].T,
    extent=[xmin, xmax, ymin, ymax],
    aspect="equal"
)

ax.set(xlabel="x [µm]", ylabel="y [µm]", title=f"Nx = {Nx2} - Ny = {Ny2}")

# define majors (with label) and minors (without label)
ax.set_xticks(xticks_major)              # majors
ax.set_xticks(xticks_all, minor=True)    # minors (dense grade)

ax.set_yticks(yticks_major)
ax.set_yticks(yticks_all, minor=True)

# labels formatation
ax.tick_params(axis='x', labelrotation=90)
ax.xaxis.set_major_formatter(ScalarFormatter(useOffset=False))
ax.yaxis.set_major_formatter(ScalarFormatter(useOffset=False))

# grid in majors and minors
ax.grid(which='both', linewidth=0.5)
# (optional) different styles:
# ax.grid(which='major', linewidth=0.8)
# ax.grid(which='minor', linewidth=0.3, alpha=0.6)

plt.tight_layout()
plt.show()

# %%
ERxx = ER2[1::2, 0::2]
ERyy = ER2[0::2, 1::2]
ERzz = ER2[0::2, 0::2]

URxx = UR2[0::2, 1::2]
URyy = UR2[1::2, 0::2]
URzz = UR2[1::2, 1::2]

# %%
M = ERxx.size
assert M == (Nx * Ny), "Inconsistência entre tamanhos da malha e subamostragem Yee."

def diag_from_grid(G):
    return diags(G.reshape(-1, order='F'), 0, shape=(M, M), format='csr')

ERxx = diag_from_grid(ERxx)
ERyy = diag_from_grid(ERyy)
ERzz = diag_from_grid(ERzz)

URxx = diag_from_grid(URxx)
URyy = diag_from_grid(URyy)
URzz = diag_from_grid(URzz)

# %%
k0 = 2*np.pi/lam0
# Dif. Operators
DEX, DEY, DHX, DHY = diff_opr(Nx,Ny,dx,dy)
# Norm
DEX = DEX/k0
DEY = DEY/k0
DHX = DHX/k0
DHY = DHY/k0

# %%
def inv_diag(diag_mat: csr_matrix) -> csr_matrix:
    """Retorna a inversa de uma matriz diagonal esparsa (CSR)."""
    d = diag_mat.diagonal()
    return diags(1.0 / d, format='csr')

# %%
ERzz_inv = inv_diag(ERzz)
URzz_inv = inv_diag(URzz)

# %%
P11 = DEX @ ERzz_inv @ DHY
P12 = -(DEX @ ERzz_inv @ DHX + URyy)
P21 = DEY @ ERzz_inv @ DHY + URxx
P22 = -(DEY @ ERzz_inv @ DHX) 

P = bmat([[P11, P12],
          [P21, P22]], format='csr')

Q11 = DHX @ URzz_inv @ DEY
Q12 = -(DHX @ URzz_inv @ DEX + ERyy)
Q21 = DHY @ URzz_inv @ DEY + ERxx
Q22 = -(DHY @ URzz_inv @ DEX)

Q = bmat([[Q11, Q12],
          [Q21, Q22]], format='csr')

# EIGENVALUE PROBLEM
A = (P @ Q).tocsr()
ev_target = - (rib_n2**2)    # shift-invert target (iqual to MATLAB)

vals, Exy = eigs(A, k=nmodes, sigma=ev_target)
d = np.sqrt(vals)
NEFF = np.imag(d)

# %%
NEFF
# Out:
# array([3.37899027, 3.36862631, 3.34295121, 3.33259204, 3.31610619])

# %%
Ex = Exy[:M, :]
Ey = Exy[M:2*M, :]

Hxy = Q @ Exy
Hxy = Hxy @ diags(-1.0/d, format='csr')

Hx = Hxy[:M, :]
Hy = Hxy[M:2*M, :]

# Ez and Hz calculation

Ez = URzz_inv @ (DHX @ Hy - DHY @ Hx)
Hz = URzz_inv @ (DEX @ Ey - DEY @ Ex)

# %%
ex_lin = np.reshape(Ex[:,0], (Nx, Ny), order='F')
fig, ax = plt.subplots(figsize=(10, 10))
im = ax.imshow(np.real(ex_lin.T), extent=np.array([xa.min(), xa.max(), ya.max(), ya.min()]), aspect="equal", cmap = "viridis") ''' im -> Vincula a imagem ao eixo (onde estão as informações da imagem) '''
cbar = plt.colorbar(im, ax=ax, fraction=0.023, pad=0.045) ''' im -> Vincula a colorbar a imagem, ax -> Passa informações a ela, fraction -> Informa o tamanho da colorbar e pad -> Informa a distância dela '''

# %%
ex = Ex[:, 1].reshape((Nx, Ny), order='F')
fig, ax = plt.subplots(figsize=(10, 10))
im = ax.imshow(np.real(ex.T), cmap="viridis")
cbar = plt.colorbar(im, ax=ax, fraction=0.023, pad=0.045)
